# %% [markdown]
# ## This notebook will show you how to load the excel data with pandas
# * I'm using the [department excel file](https://docs.google.com/spreadsheets/d/1M0n0m8BzuJcHOy7iUnZMCbLg5ITpCftkP2b4k6mx_pA/edit?usp=sharing), which contains data on students' grades in several subjects, in this example. This excel has a seperate sheet for different departments (Information technology department, Computer science department, Mechanical department, Electronics department) and they are of different format.

# %% [markdown]
# ## Pandas
# * [Pandas](https://pandas.pydata.org/docs/index.html) is a data manipulation and analysis library for python programming language. It provides data structures and functions for working with the structured data.

# %% [markdown]
# ## Setup
# * To install and import the [pandas](https://pandas.pydata.org/docs/index.html) library run the following codes
#     * pip install pandas
#     * import pandas as pd
#     <br>
#     <B>Note</B>: Ensure the latest version of python is installed in your machine.

# %%
import pandas as pd

# %% [markdown]
# ## Loading the Excel data with pandas
# * To load the excel data with pandas we can use the [read_excel ](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html) function provided by the pandas.

# %%
pd.read_excel('Department.xlsx')
# Out:
#    This sheet is about the computer science department Unnamed: 1 Unnamed: 2  \
# 0               This department has total 15 students         NaN        NaN
# 1   this sheet gives you the grades for all the st...         NaN        NaN
# 2                                          First Name         ADM       DBMS
# 3                                           Manvitha        100.0       98.0
# 4                                                 Joe           -       35.0
# 5                                                Ally        35.0       46.0
# 6                                                Alex        30.0          -
# 7                                              Bailey        32.0       23.0
# 8                                              Bradey        45.0          -
# 9                                              Cooper        65.0       76.0
# 10                                              David        54.0       21.0
# 11                                              Ellis           -       32.0
# 12                                             Finely        23.0       31.0
# 13                                              Nancy        98.0       99.0
# 14                                              Steve        77.0       78.0
# 15                                             Eleven        12.0       34.0
# 16                                              Damon        43.0       67.0
# 17                                             Hayley        56.0       76.0
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         DAA        NLP     Python         CN
# 3        87.0       99.0       90.0       90.0
# 4        30.0       34.0       35.0       56.0
# 5        70.0       23.0       24.0       34.0
# 6        34.0       35.0       36.0       12.0
# 7        24.0       42.0       35.0       53.0
# 8        56.0       65.0       70.0       54.0
# 9        86.0          -       23.0       43.0
# 10       23.0       33.0       34.0          -
# 11       23.0       21.0       34.0       42.0
# 12          -       45.0       56.0       61.0
# 13      100.0       92.0       91.0       90.0
# 14       87.0          -       98.0          -
# 15       56.0       67.0       35.0      100.0
# 16       89.0       98.0       45.0       60.0
# 17          -       21.0       54.0       99.0

# %% [markdown]
# * The API loads the first sheet by default since `sheet_name` is set to 0 (first sheet index) as shown in the [API doc](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html).
# * To load specific sheet from the excel, then we can pass on these optional parameter `sheet_name` either with index or name of the sheet.
#     * For ex: To load specific sheet from the given excel file using its name, below is the sample code:

# %%
data = pd.read_excel('Department.xlsx', sheet_name='Mechanical')
data
# Out:
#         This sheet is about the Mechanical department Unnamed: 1 Unnamed: 2  \
# 0               This department has total 15 students        NaN        NaN
# 1   this sheet gives you the grades for all the st...        NaN        NaN
# 2                                          First Name        ADM       DBMS
# 3                                           Manvitha       100.0       98.0
# 4                                                 Joe          -       35.0
# 5                                                Ally       35.0       46.0
# 6                                                Alex       30.0          -
# 7                                              Bailey       32.0       23.0
# 8                                              Bradey       45.0          -
# 9                                              Cooper       65.0       76.0
# 10                                              David       54.0       21.0
# 11                                              Ellis          -       32.0
# 12                                             Finely       23.0       31.0
# 13                                              Nancy       98.0       99.0
# 14                                              Steve       77.0       78.0
# 15                                             Eleven       12.0       34.0
# 16                                              Damon       43.0       67.0
# 17                                             Hayley       56.0       76.0
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         DAA        NLP     Python         CN
# 3        87.0       99.0       90.0       90.0
# 4        30.0       34.0       35.0       56.0
# 5        70.0       23.0       24.0       34.0
# 6        34.0       35.0       36.0       12.0
# 7        24.0       42.0       35.0       53.0
# 8        56.0       65.0       70.0       54.0
# 9        86.0          -       23.0       43.0
# 10       23.0       33.0       34.0          -
# 11       23.0       21.0       34.0       42.0
# 12          -       45.0       56.0       61.0
# 13      100.0       92.0       91.0       90.0
# 14       87.0          -       98.0          -
# 15       56.0       67.0       35.0      100.0
# 16       89.0       98.0       45.0       60.0
# 17          -       21.0       54.0       99.0

# %% [markdown]
# ## Exercise
# * Try loading the specific sheet from the given excel file using its index.
# * For solution refer to the [documentaion](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)

# %% [markdown]
# However, when we look at the above output, it is showing first row as its header in the display table instead of the actual header available at the 4th row (index 3).

# %% [markdown]
# ## Dealing with the Headers in the excel file.
# * By default, [read_excel](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html) API considers the first row as its header. In order to read the headers from the right location there are couple of options.

# %% [markdown]
# ## Approach 1: Using `skiprows` parameter.
# * Using `skiprows` optional parameter to specify how many rows to skip in order to read the header from the given excel.

# %%
data = pd.read_excel('Department.xlsx', sheet_name='Mechanical', skiprows=3)
data
# Out:
#    First Name    ADM  DBMS    DAA   NLP  Python     CN
# 0   Manvitha   100.0  98.0   87.0  99.0    90.0   90.0
# 1         Joe      -  35.0   30.0  34.0    35.0   56.0
# 2        Ally   35.0  46.0   70.0  23.0    24.0   34.0
# 3        Alex   30.0     -   34.0  35.0    36.0   12.0
# 4      Bailey   32.0  23.0   24.0  42.0    35.0   53.0
# 5      Bradey   45.0     -   56.0  65.0    70.0   54.0
# 6      Cooper   65.0  76.0   86.0     -    23.0   43.0
# 7       David   54.0  21.0   23.0  33.0    34.0      -
# 8       Ellis      -  32.0   23.0  21.0    34.0   42.0
# 9      Finely   23.0  31.0      -  45.0    56.0   61.0
# 10      Nancy   98.0  99.0  100.0  92.0    91.0   90.0
# 11      Steve   77.0  78.0   87.0     -    98.0      -
# 12     Eleven   12.0  34.0   56.0  67.0    35.0  100.0
# 13      Damon   43.0  67.0   89.0  98.0    45.0   60.0
# 14     Hayley   56.0  76.0      -  21.0    54.0   99.0

# %% [markdown]
# ## Approach 2: Using the `header` parameter.
# * We can use optional parameter `header` with the row index as shown below:

# %%
data = pd.read_excel('Department.xlsx', sheet_name='Mechanical', header=3)
data
# Out:
#    First Name    ADM  DBMS    DAA   NLP  Python     CN
# 0   Manvitha   100.0  98.0   87.0  99.0    90.0   90.0
# 1         Joe      -  35.0   30.0  34.0    35.0   56.0
# 2        Ally   35.0  46.0   70.0  23.0    24.0   34.0
# 3        Alex   30.0     -   34.0  35.0    36.0   12.0
# 4      Bailey   32.0  23.0   24.0  42.0    35.0   53.0
# 5      Bradey   45.0     -   56.0  65.0    70.0   54.0
# 6      Cooper   65.0  76.0   86.0     -    23.0   43.0
# 7       David   54.0  21.0   23.0  33.0    34.0      -
# 8       Ellis      -  32.0   23.0  21.0    34.0   42.0
# 9      Finely   23.0  31.0      -  45.0    56.0   61.0
# 10      Nancy   98.0  99.0  100.0  92.0    91.0   90.0
# 11      Steve   77.0  78.0   87.0     -    98.0      -
# 12     Eleven   12.0  34.0   56.0  67.0    35.0  100.0
# 13      Damon   43.0  67.0   89.0  98.0    45.0   60.0
# 14     Hayley   56.0  76.0      -  21.0    54.0   99.0

# %% [markdown]
# ## Loading Multiple sheets.
# * If our excel file contains multiple sheets, we can load all of them into a dictionary of dataframes using the parameter `sheet_name=None`. The name of the sheet will be used as a key in the dictionary.

# %%
data = pd.read_excel('Department.xlsx', sheet_name=None, header=3)
for sheet_name, df in data.items():
    print("The name of the sheet is: ", sheet_name)
    print("The contents of the sheet are: ")
    print()
    print(df)
    print('\n')
# Out:
# The name of the sheet is:  Information
# The contents of the sheet are:
#
#    First Name    ADM  DBMS    DAA   NLP  Python     CN
# 0   Manvitha   100.0  98.0   87.0  99.0    90.0   90.0
# 1         Joe      -  35.0   30.0  34.0    35.0   56.0
# 2        Ally   35.0  46.0   70.0  23.0    24.0   34.0
# 3        Alex   30.0     -   34.0  35.0    36.0   12.0
# 4      Bailey   32.0  23.0   24.0  42.0    35.0   53.0
# 5      Bradey   45.0     -   56.0  65.0    70.0   54.0
# 6      Cooper   65.0  76.0   86.0     -    23.0   43.0
# 7       David   54.0  21.0   23.0  33.0    34.0      -
# 8       Ellis      -  32.0   23.0  21.0    34.0   42.0
# 9      Finely   23.0  31.0      -  45.0    56.0   61.0
# 10      Nancy   98.0  99.0  100.0  92.0    91.0   90.0
# 11      Steve   77.0  78.0   87.0     -    98.0      -
# 12     Eleven   12.0  34.0   56.0  67.0    35.0  100.0
# 13      Damon   43.0  67.0   89.0  98.0    45.0   60.0
# 14     Hayley   56.0  76.0      -  21.0    54.0   99.0
#
#
# The name of the sheet is:  Computer science
# The contents of the sheet are:
#
#    First Name    ADM  DBMS    DAA   NLP  Python     CN
# 0   Manvitha   100.0  98.0   87.0  99.0    90.0   90.0
# 1         Joe      -  35.0   30.0  34.0    35.0   56.0
# 2        Ally   35.0  46.0   70.0  23.0    24.0   34.0
# 3        Alex   30.0     -   34.0  35.0    36.0   12.0
# 4      Bailey   32.0  23.0   24.0  42.0    35.0   53.0
# 5      Bradey   45.0     -   56.0  65.0    70.0   54.0
# 6      Cooper   65.0  76.0   86.0     -    23.0   43.0
# 7       David   54.0  21.0   23.0  33.0    34.0      -
# 8       Ellis      -  32.0   23.0  21.0    34.0   42.0
# 9      Finely   23.0  31.0      -  45.0    56.0   61.0
# 10      Nancy   98.0  99.0  100.0  92.0    91.0   90.0
# 11      Steve   77.0  78.0   87.0     -    98.0      -
# 12     Eleven   12.0  34.0   56.0  67.0    35.0  100.0
# 13      Damon   43.0  67.0   89.0  98.0    45.0   60.0
# 14     Hayley   56.0  76.0   70.0  21.0    54.0   99.0
#
#
# The name of the sheet is:  Mechanical
# The contents of the sheet are:
#
#    First Name    ADM  DBMS    DAA   NLP  Python     CN
# 0   Manvitha   100.0  98.0   87.0  99.0    90.0   90.0
# 1         Joe      -  35.0   30.0  34.0    35.0   56.0
# 2        Ally   35.0  46.0   70.0  23.0    24.0   34.0
# 3        Alex   30.0     -   34.0  35.0    36.0   12.0
# 4      Bailey   32.0  23.0   24.0  42.0    35.0   53.0
# 5      Bradey   45.0     -   56.0  65.0    70.0   54.0
# 6      Cooper   65.0  76.0   86.0     -    23.0   43.0
# 7       David   54.0  21.0   23.0  33.0    34.0      -
# 8       Ellis      -  32.0   23.0  21.0    34.0   42.0
# 9      Finely   23.0  31.0      -  45.0    56.0   61.0
# 10      Nancy   98.0  99.0  100.0  92.0    91.0   90.0
# 11      Steve   77.0  78.0   87.0     -    98.0      -
# 12     Eleven   12.0  34.0   56.0  67.0    35.0  100.0
# 13      Damon   43.0  67.0   89.0  98.0    45.0   60.0
# 14     Hayley   56.0  76.0      -  21.0    54.0   99.0
#
#
# The name of the sheet is:  Electronics
# The contents of the sheet are:
#
#    First Name    ADM  DBMS    DAA   NLP  Python     CN
# 0   Manvitha   100.0  98.0   87.0  99.0    90.0   90.0
# 1         Joe      -  35.0   30.0  34.0    35.0   56.0
# 2        Ally   35.0  46.0   70.0  23.0    24.0   34.0
# 3        Alex   30.0     -   34.0  35.0    36.0   12.0
# 4      Bailey   32.0  23.0   24.0  42.0    35.0   53.0
# 5      Bradey   45.0     -   56.0  65.0    70.0   54.0
# 6      Cooper   65.0  76.0   86.0     -    23.0   43.0
# 7       David   54.0  21.0   23.0  33.0    34.0      -
# 8       Ellis      -  32.0   23.0  21.0    34.0   42.0
# 9      Finely   23.0  31.0      -  45.0    56.0   61.0
# 10      Nancy   98.0  99.0  100.0  92.0    91.0   90.0
# 11      Steve   77.0  78.0   87.0     -    98.0      -
# 12     Eleven   12.0  34.0   56.0  67.0    35.0  100.0
# 13      Damon   43.0  67.0   89.0  98.0    45.0   60.0
# 14     Hayley   56.0  76.0      -  21.0    54.0   99.0

# %% [markdown]
# ## Specifying the Datatypes for each column.
# * If you want to specify the datatype for each column we can do so by using the `dtype` parameter of the [read_excel](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html) function.
# * We can provide list of key/value pairs into `dtype` parameter where `key` is the column name and `value` is the type.

# %%
data = pd.read_excel('Department.xlsx', sheet_name=None, header=3, dtype={'First Name': str, 'ADM': float, 'DBMS': float, 'DAA':float, 'NLP':float, 'Python':float, 'CN':float})
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:789, in ParserBase._cast_types(self, values, cast_type, column)
#     788 try:
# --> 789     values = astype_nansafe(values, cast_type, copy=True, skipna=True)
#     790 except ValueError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1181, in astype_nansafe(arr, dtype, copy, skipna)
#    1179 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1180     # Explicit copy, or required since NumPy can't view from / to object.
# -> 1181     return arr.astype(dtype, copy=True)
#    1183 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 data = pd.read_excel('Department.xlsx', sheet_name=None, header=3, dtype={'First Name': str, 'ADM': float, 'DBMS': float, 'DAA':float, 'NLP':float, 'Python':float, 'CN':float})
#       2 data
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:465, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#     464 try:
# --> 465     data = io.parse(
#     466         sheet_name=sheet_name,
#     467         header=header,
#     468         names=names,
#     469         index_col=index_col,
#     470         usecols=usecols,
#     471         squeeze=squeeze,
#     472         dtype=dtype,
#     473         converters=converters,
#     474         true_values=true_values,
#     475         false_values=false_values,
#     476         skiprows=skiprows,
#     477         nrows=nrows,
#     478         na_values=na_values,
#     479         keep_default_na=keep_default_na,
#     480         na_filter=na_filter,
#     481         verbose=verbose,
#     482         parse_dates=parse_dates,
#     483         date_parser=date_parser,
#     484         thousands=thousands,
#     485         decimal=decimal,
#     486         comment=comment,
#     487         skipfooter=skipfooter,
#     488         convert_float=convert_float,
#     489         mangle_dupe_cols=mangle_dupe_cols,
#     490     )
#     491 finally:
#     492     # make sure to close opened file handles
#     493     if should_close:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:1458, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1424 def parse(
#    1425     self,
#    1426     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1445     **kwds,
#    1446 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1447     """
#    1448     Parse specified sheet(s) into a DataFrame.
#    1449
#    (...)
#    1456         DataFrame from the passed in Excel file.
#    1457     """
# -> 1458     return self._reader.parse(
#    1459         sheet_name=sheet_name,
#    1460         header=header,
#    1461         names=names,
#    1462         index_col=index_col,
#    1463         usecols=usecols,
#    1464         squeeze=squeeze,
#    1465         converters=converters,
#    1466         true_values=true_values,
#    1467         false_values=false_values,
#    1468         skiprows=skiprows,
#    1469         nrows=nrows,
#    1470         na_values=na_values,
#    1471         parse_dates=parse_dates,
#    1472         date_parser=date_parser,
#    1473         thousands=thousands,
#    1474         comment=comment,
#    1475         skipfooter=skipfooter,
#    1476         convert_float=convert_float,
#    1477         mangle_dupe_cols=mangle_dupe_cols,
#    1478         **kwds,
#    1479     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py:740, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     714 try:
#     715     parser = TextParser(
#     716         data,
#     717         names=names,
#    (...)
#     737         **kwds,
#     738     )
# --> 740     output[asheetname] = parser.read(nrows=nrows)
#     742     if not squeeze or isinstance(output[asheetname], DataFrame):
#     743         if header_names:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/python_parser.py:273, in PythonParser.read(self, rows)
#     270 alldata = self._rows_to_cols(content)
#     271 data, columns = self._exclude_implicit_index(alldata)
# --> 273 conv_data = self._convert_data(data)
#     274 columns, conv_data = self._do_date_conversions(columns, conv_data)
#     276 index, columns = self._make_index(conv_data, alldata, columns, indexnamerow)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/python_parser.py:331, in PythonParser._convert_data(self, data)
#     328     clean_na_values = self.na_values
#     329     clean_na_fvalues = self.na_fvalues
# --> 331 return self._convert_to_ndarrays(
#     332     data,
#     333     clean_na_values,
#     334     clean_na_fvalues,
#     335     self.verbose,
#     336     clean_conv,
#     337     clean_dtypes,
#     338 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:603, in ParserBase._convert_to_ndarrays(self, dct, na_values, na_fvalues, verbose, converters, dtypes)
#     601                 pass
#     602         cast_type = pandas_dtype(cast_type)
# --> 603         cvals = self._cast_types(cvals, cast_type, c)
#     605 result[c] = cvals
#     606 if verbose and na_count:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py:791, in ParserBase._cast_types(self, values, cast_type, column)
#     789         values = astype_nansafe(values, cast_type, copy=True, skipna=True)
#     790     except ValueError as err:
# --> 791         raise ValueError(
#     792             f"Unable to convert column {column} to type {cast_type}"
#     793         ) from err
#     794 return values
#
# ValueError: Unable to convert column ADM to type float64

# %% [markdown]
# ## Excersie
# * Can you find out what is happening here? Why is it resulting into an error?

# %% [markdown]
# ## Handling Incompatible data
# * For the above code we are getting the error because some columns has special characters (ex: `-`) as values. Ex: column type for ADM is `float` but it has special characters (string) `-` as values.
#
# In order to recognize special strings as NA/NaN, we can use `na_values` parameter.
#
# For this data set, we can set `na_values` parameter with value as`-` in the API, so that it treats `-` data as NA or NaN. An example is shown below:

# %%
data = pd.read_excel('Department.xlsx', sheet_name='Information', header =3, dtype={'First NAme': str, 'ADM': float, 'DBMS': float,'DAA':float,'NLP':float,'Python':float,'CN':float}, na_values=['-'])
data
# Out:
#    First Name    ADM  DBMS    DAA   NLP  Python     CN
# 0   Manvitha   100.0  98.0   87.0  99.0    90.0   90.0
# 1         Joe    NaN  35.0   30.0  34.0    35.0   56.0
# 2        Ally   35.0  46.0   70.0  23.0    24.0   34.0
# 3        Alex   30.0   NaN   34.0  35.0    36.0   12.0
# 4      Bailey   32.0  23.0   24.0  42.0    35.0   53.0
# 5      Bradey   45.0   NaN   56.0  65.0    70.0   54.0
# 6      Cooper   65.0  76.0   86.0   NaN    23.0   43.0
# 7       David   54.0  21.0   23.0  33.0    34.0    NaN
# 8       Ellis    NaN  32.0   23.0  21.0    34.0   42.0
# 9      Finely   23.0  31.0    NaN  45.0    56.0   61.0
# 10      Nancy   98.0  99.0  100.0  92.0    91.0   90.0
# 11      Steve   77.0  78.0   87.0   NaN    98.0    NaN
# 12     Eleven   12.0  34.0   56.0  67.0    35.0  100.0
# 13      Damon   43.0  67.0   89.0  98.0    45.0   60.0
# 14     Hayley   56.0  76.0    NaN  21.0    54.0   99.0

# %% [markdown]
# ## Excercise
# * Load the 'Computer science' sheet from Department1 excel [file](https://docs.google.com/spreadsheets/d/1R-Mzz1hEwMOMXCQfz_EBgDeaE6mj31dWsyLzn8zxePA/edit?usp=sharing) using pandas `read_excel` api.
# * The data is represented in European format. Ex: 14th row and DAA column has value `70,5`. Use appropriate optional parameter to treat `,` as decimal point and ensure it displays as `70.5`.

# %% [markdown]
# ## More references:
# https://sparkbyexamples.com/pandas/pandas-read-excel-with-examples/
#
# https://www.digitalocean.com/community/tutorials/pandas-read_excel-reading-excel-file-in-python
